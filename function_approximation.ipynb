# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
from IPython.display import clear_output

from tqdm import tqdm

from utils import *
from linear import LinearApprox
from taylorseries import TaylorSeries
from neural_network import *

# %%
## Adding another function for visualziation. Non-smooth and non-differentiable.
## Transforations on the floor function are for better visibility when graphing.

def wide_floor(x):
    return -np.floor(x*1/2)

# %% [markdown]
# # Function Approximation with Taylor Series, Linear Regression, and Neural Networks
#
# This project was inspired by some late night scrolling on Instagram. There was this real that simply showed the connection between the Taylor Series and how to

# %% [markdown]
# ## Taylor Series

# %%
taylor_series = TaylorSeries()
taylor_series.set_graph_params(size = 10000, lower_bound = -10, upper_bound = 10)
taylor_series.visualize_plots(N = 10, A = 2.5, func = "cosine")

# %% [markdown]
# ## Linear Regression

# %%
linear_approx = LinearApprox()
linear_approx.visualize_plots(N= 5, func = "cosine", A = 0)

# %%
# Out:
# array([ 2.78000e-02, -2.20100e-01, -8.43000e-02,  1.27000e-01,
#         1.33900e-01,  1.70900e-01, -1.46900e-01, -1.08630e+00,
#         1.07000e-02,  3.70860e+00,  5.70600e-01, -1.03866e+01,
#        -2.10370e+00,  2.45096e+01,  4.78940e+00, -4.63370e+01,
#        -7.05240e+00,  6.24739e+01,  5.26510e+00, -4.49461e+01])

# %%
linear_approx = LinearApprox()
linear_approx.visualize_plots(N= 20, func = wide_floor)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[51], line 2
#       1 linear_approx = LinearApprox()
# ----> 2 linear_approx.visualize_plots(N= 20, func = wide_floor)
#
# File ~/Desktop/functionApproximation/linear.py:77, in LinearApprox.visualize_plots(self, N, func, A)
#      75 display(plt.gcf())
#      76 plt.close()
# ---> 77 time.sleep(0.5)
#      78 clear_output(wait=True)
#
# KeyboardInterrupt:

# %%
for i, v in enumerate(linear_approx.coefs):
    print(f"Order {i+1} coef: {v:.04f}")
# Out:
# Order 1 coef: 0.0277
# Order 2 coef: -0.2201
# Order 3 coef: -0.0842
# Order 4 coef: 0.1272
# Order 5 coef: 0.1338
# Order 6 coef: 0.1702
# Order 7 coef: -0.1466
# Order 8 coef: -1.0834
# Order 9 coef: 0.0101
# Order 10 coef: 3.6981
# Order 11 coef: 0.5722
# Order 12 coef: -10.3523
# Order 13 coef: -2.1076
# Order 14 coef: 24.4151
# Order 15 coef: 4.7974
# Order 16 coef: -46.1319
# Order 17 coef: -7.0638
# Order 18 coef: 62.1622
# Order 19 coef: 5.2735
# Order 20 coef: -44.6978

# %%
linear_approx = LinearApprox()
linear_approx.set_graph_params(size = 1000)
linear_approx.visualize_plots(N= 10, func = cosine_with_noise)

# %%
for i, v in enumerate(linear_approx.coefs):
    print(f"Order {i+1} coef: {v:.04f}")
# Out:
# Order 1 coef: -0.0009
# Order 2 coef: -0.8097
# Order 3 coef: 0.0034
# Order 4 coef: 0.6841
# Order 5 coef: -0.0034
# Order 6 coef: -0.5018
# Order 7 coef: 0.0024
# Order 8 coef: 0.2831
# Order 9 coef: -0.0009
# Order 10 coef: -0.0914

# %%
linear_approx.plot_function(N = 170, func = wide_floor)

# %% [markdown]
# ## Neural Network

# %%
from neural_network import *

# %%
N = 10
fcnn_approx = FCNN_approx()
fcnn_approx.initialize(N = N, func = np.cos)
y_pred, _ = fcnn_approx.train([N,16*N, 8*N, 4*N,2*N,N,1], initial_lr=0.01, decay_rate = 0.995, decay_steps = 500, epochs = 5000, delay = 0.0)

# %%
N = 10
fcnn_approx = FCNN_approx()
fcnn_approx.initialize(N = N, func = cosine_with_noise)
y_pred, _ = fcnn_approx.train([N,16*N, 8*N, 4*N,2*N,N,1], initial_lr=0.01, decay_rate = 0.995, decay_steps = 500, epochs = 5000, delay = 0.0)

# %%
N = 10
fcnn_approx = FCNN_approx()
fcnn_approx.initialize(N = N, size = 500, func = wide_floor)
y_pred, _ = fcnn_approx.train([N,16*N, 8*N, 4*N,2*N,N,1], initial_lr=0.01, decay_rate = 0.995, decay_steps = 500, epochs = 5000, delay = 0.0)
